# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Martynas\AppData\Local\Temp\ipykernel_10376\2937650959.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
labels = ('vardas', 'pavarde', 'amzius')
zmogus = ('geras', 'zmogelis', 33)
print(labels, zmogus)
# Out:
# ('vardas', 'pavarde', 'amzius') ('geras', 'zmogelis', 33)

# %%
pd.Series(data=zmogus)
# Out:
# 0       geras
# 1    zmogelis
# 2          33
# dtype: object

# %%
pd.Series(data=zmogus, index=labels)
# Out:
# vardas        geras
# pavarde    zmogelis
# amzius           33
# dtype: object

# %%
zmogus_dict = {
    'vardas': 'Smagus',
    'pavarde': 'Giedriukas',
    'amzius': 36
}
print(zmogus_dict)
# Out:
# {'vardas': 'Smagus', 'pavarde': 'Giedriukas', 'amzius': 36}

# %%
zmogus_pd = pd.Series(data=zmogus_dict)
zmogus_pd
# Out:
# vardas         Smagus
# pavarde    Giedriukas
# amzius             36
# dtype: object

# %%
pd.Series(zmogus, labels)
# Out:
# vardas        geras
# pavarde    zmogelis
# amzius           33
# dtype: object

# %%
zmogus_pd['vardas']
# Out:
# 'Smagus'

# %%
miestai = pd.Series((500, 400, 300, 200), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
miestai
# Out:
# Vilnius     500
# Kaunas      400
# Klaipeda    300
# Siauliai    200
# dtype: int64

# %%
augimas = pd.Series((1.5, 1.3, 0.9, 0.7),('Vilius', 'Kaunas', 'Siauliai', 'Klaipeda'))
augimas
# Out:
# Vilius      1.5
# Kaunas      1.3
# Siauliai    0.9
# Klaipeda    0.7
# dtype: float64

# %%
betko7x7 = np.random.randint(10, 100, (7,7))
betko7x7
# Out:
# array([[62, 61, 91, 61, 72, 88, 93],
#        [22, 84, 72, 78, 75, 84, 55],
#        [11, 51, 67, 11, 19, 99, 70],
#        [44, 81, 47, 22, 98, 33, 29],
#        [89, 11, 21, 20, 44, 56, 39],
#        [71, 91, 97, 21, 91, 54, 89],
#        [51, 86, 35, 14, 37, 45, 24]])

# %%
miestu_skaiciai = pd.DataFrame(
    betko7x7,
    [2000, 2004, 2008, 2012, 2016, 2020, 2024],
    ['Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai', 'Panevezys', 'Alytus', 'Kavarskas']
)
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Kavarskas
# 2000       62      61        91        61         72      88         93
# 2004       22      84        72        78         75      84         55
# 2008       11      51        67        11         19      99         70
# 2012       44      81        47        22         98      33         29
# 2016       89      11        21        20         44      56         39
# 2020       71      91        97        21         91      54         89
# 2024       51      86        35        14         37      45         24

# %%
print(type(miestu_skaiciai['Kaunas']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
miestu_skaiciai['Kaunas']
# Out:
# 2000    61
# 2004    84
# 2008    51
# 2012    81
# 2016    11
# 2020    91
# 2024    86
# Name: Kaunas, dtype: int32

# %%
miestu_skaiciai [['Vilnius', 'Kaunas']]
# Out:
#       Vilnius  Kaunas
# 2000       62      61
# 2004       22      84
# 2008       11      51
# 2012       44      81
# 2016       89      11
# 2020       71      91
# 2024       51      86

# %%
miestu_skaiciai['Vilnius'][2000] = 99
miestu_skaiciai
# Out:
# C:\Users\Martynas\AppData\Local\Temp\ipykernel_10808\3820624449.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   miestu_skaiciai['Vilnius'][2000] = 99
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Kavarskas
# 2000       99      61        91        61         72      88         93
# 2004       22      84        72        78         75      84         55
# 2008       11      51        67        11         19      99         70
# 2012       44      81        47        22         98      33         29
# 2016       89      11        21        20         44      56         39
# 2020       71      91        97        21         91      54         89
# 2024       51      86        35        14         37      45         24

# %%
miestu_skaiciai.loc[2004]
# Out:
# Vilnius      22
# Kaunas       84
# Klaipeda     72
# Siauliai     78
# Panevezys    75
# Alytus       84
# Kavarskas    55
# Name: 2004, dtype: int32

# %%
kazluruda = pd.Series(np.random.randint(10, 99, 7), np.arange(2000, 25, 4))
kazluruda
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 kazluruda = pd.Series(np.random.randint(10, 99, 7), np.arange(2000, 25, 4))
#       2 kazluruda
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\core\series.py:574, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     572     index = default_index(len(data))
#     573 elif is_list_like(data):
# --> 574     com.require_length_match(data, index)
#     576 # create/copy the manager
#     577 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (7) does not match length of index (0)

# %%
miestu_skaiciai['Kazlu Ruda'] = kazluruda
miestu_skaiciai
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 miestu_skaiciai['Kazlu Ruda'] = kazluruda
#       2 miestu_skaiciai
#
# NameError: name 'kazluruda' is not defined

# %%
miestu_skaiciai.drop('Siauliai', axis = 1, inplace=True)

# %%
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Kavarskas
# 2000       99      61        91         72      88         93
# 2004       22      84        72         75      84         55
# 2008       11      51        67         19      99         70
# 2012       44      81        47         98      33         29
# 2016       89      11        21         44      56         39
# 2020       71      91        97         91      54         89
# 2024       51      86        35         37      45         24

# %%
miestu_skaiciai.drop('Klaipeda', axis=1, inplace=True)
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Panevezys  Alytus  Kavarskas
# 2000       99      61         72      88         93
# 2004       22      84         75      84         55
# 2008       11      51         19      99         70
# 2012       44      81         98      33         29
# 2016       89      11         44      56         39
# 2020       71      91         91      54         89
# 2024       51      86         37      45         24

# %%
miestu_skaiciai.drop(2008)
# Out:
#       Vilnius  Kaunas  Panevezys  Alytus  Kavarskas
# 2000       99      61         72      88         93
# 2004       22      84         75      84         55
# 2012       44      81         98      33         29
# 2016       89      11         44      56         39
# 2020       71      91         91      54         89
# 2024       51      86         37      45         24

# %%
miestu_skaiciai.loc[2008]
# Out:
# Vilnius      11
# Kaunas       51
# Panevezys    19
# Alytus       99
# Kavarskas    70
# Name: 2008, dtype: int32

# %%
miestu_skaiciai.iloc[3]
# Out:
# Vilnius      44
# Kaunas       81
# Panevezys    98
# Alytus       33
# Kavarskas    29
# Name: 2012, dtype: int32

# %%
miestu_skaiciai['Vilnius'][2020]
# Out:
# 71

# %%
miestu_skaiciai.loc[2020, 'Vilnius']
# Out:
# 71

# %%
miestu_skaiciai.loc[[2012, 2020, 2024], ['Kaunas', 'Alytus']]
# Out:
#       Kaunas  Alytus
# 2012      81      33
# 2020      91      54
# 2024      86      45

# %%
miestu_skaiciai[['Kaunas', 'Alytus']]
# Out:
#       Kaunas  Alytus
# 2000      61      88
# 2004      84      84
# 2008      51      99
# 2012      81      33
# 2016      11      56
# 2020      91      54
# 2024      86      45

# %%
miestu_skaiciai[(miestu_skaiciai['Vilnius'] > 50)] & (miestu_skaiciai['Kaunas'] > 80)
# Out:
#        2000   2004   2008   2012   2016   2020   2024  Alytus  Kaunas  \
# 2000  False  False  False  False  False  False  False   False   False
# 2016  False  False  False  False  False  False  False   False   False
# 2020  False  False  False  False  False  False  False   False   False
# 2024  False  False  False  False  False  False  False   False   False
#
#       Kavarskas  Panevezys  Vilnius
# 2000      False      False    False
# 2016      False      False    False
# 2020      False      False    False
# 2024      False      False    False

# %%
miestu_skaiciai.reset_index()
# Out:
#    index  Vilnius  Kaunas  Panevezys  Alytus  Kavarskas
# 0   2000       99      61         72      88         93
# 1   2004       22      84         75      84         55
# 2   2008       11      51         19      99         70
# 3   2012       44      81         98      33         29
# 4   2016       89      11         44      56         39
# 5   2020       71      91         91      54         89
# 6   2024       51      86         37      45         24

# %%
be_indekso = miestu_skaiciai.reset_index()
be_indekso
# Out:
#    index  Vilnius  Kaunas  Panevezys  Alytus  Kavarskas
# 0   2000       99      61         72      88         93
# 1   2004       22      84         75      84         55
# 2   2008       11      51         19      99         70
# 3   2012       44      81         98      33         29
# 4   2016       89      11         44      56         39
# 5   2020       71      91         91      54         89
# 6   2024       51      86         37      45         24

# %%
be_indekso['Utena'] = np.random.randint(10, 71, 7)
be_indekso
# Out:
#    index  Vilnius  Kaunas  Panevezys  Alytus  Kavarskas  Utena
# 0   2000       99      61         72      88         93     65
# 1   2004       22      84         75      84         55     61
# 2   2008       11      51         19      99         70     69
# 3   2012       44      81         98      33         29     59
# 4   2016       89      11         44      56         39     53
# 5   2020       71      91         91      54         89     24
# 6   2024       51      86         37      45         24     50

# %%
su_utena = be_indekso.set_index('index')
su_utena
# Out:
#        Vilnius  Kaunas  Panevezys  Alytus  Kavarskas  Utena
# index
# 2000        99      61         72      88         93     65
# 2004        22      84         75      84         55     61
# 2008        11      51         19      99         70     69
# 2012        44      81         98      33         29     59
# 2016        89      11         44      56         39     53
# 2020        71      91         91      54         89     24
# 2024        51      86         37      45         24     50

# %%
##antra dalis

# %%
su_nuostoliu = su_utena[su_utena > 20]
su_nuostoliu
# Out:
#        Vilnius  Kaunas  Panevezys  Alytus  Kavarskas  Utena
# index
# 2000      99.0    61.0       72.0      88         93     65
# 2004      22.0    84.0       75.0      84         55     61
# 2008       NaN    51.0        NaN      99         70     69
# 2012      44.0    81.0       98.0      33         29     59
# 2016      89.0     NaN       44.0      56         39     53
# 2020      71.0    91.0       91.0      54         89     24
# 2024      51.0    86.0       37.0      45         24     50

# %%
su_nuostoliu.isnull()
# Out:
#        Vilnius  Kaunas  Panevezys  Alytus  Kavarskas  Utena
# index
# 2000     False   False      False   False      False  False
# 2004     False   False      False   False      False  False
# 2008      True   False       True   False      False  False
# 2012     False   False      False   False      False  False
# 2016     False    True      False   False      False  False
# 2020     False   False      False   False      False  False
# 2024     False   False      False   False      False  False

# %%
su_nuostoliu.isnull().sum()
# Out:
# Vilnius      1
# Kaunas       1
# Panevezys    1
# Alytus       0
# Kavarskas    0
# Utena        0
# dtype: int64

# %%
su_nuostoliu['Vilnius'].isnull().sum()
# Out:
# 1

# %%
su_nuostoliu['Vilnius'].isnull()
# Out:
# index
# 2000    False
# 2004    False
# 2008     True
# 2012    False
# 2016    False
# 2020    False
# 2024    False
# Name: Vilnius, dtype: bool

# %%
su_nuostoliu.dropna()
# Out:
#        Vilnius  Kaunas  Panevezys  Alytus  Kavarskas  Utena
# index
# 2000      99.0    61.0       72.0      88         93     65
# 2004      22.0    84.0       75.0      84         55     61
# 2012      44.0    81.0       98.0      33         29     59
# 2020      71.0    91.0       91.0      54         89     24
# 2024      51.0    86.0       37.0      45         24     50

# %%
su_nuostoliu.dropna(axis=1)
# Out:
#        Alytus  Kavarskas  Utena
# index
# 2000       88         93     65
# 2004       84         55     61
# 2008       99         70     69
# 2012       33         29     59
# 2016       56         39     53
# 2020       54         89     24
# 2024       45         24     50

# %%
su_nuostoliu.dropna(thresh=6)
# Out:
#        Vilnius  Kaunas  Panevezys  Alytus  Kavarskas  Utena
# index
# 2000      99.0    61.0       72.0      88         93     65
# 2004      22.0    84.0       75.0      84         55     61
# 2012      44.0    81.0       98.0      33         29     59
# 2020      71.0    91.0       91.0      54         89     24
# 2024      51.0    86.0       37.0      45         24     50

# %%
su_nuostoliu.fillna('kiauras')
# Out:
#        Vilnius   Kaunas Panevezys  Alytus  Kavarskas  Utena
# index
# 2000      99.0     61.0      72.0      88         93     65
# 2004      22.0     84.0      75.0      84         55     61
# 2008   kiauras     51.0   kiauras      99         70     69
# 2012      44.0     81.0      98.0      33         29     59
# 2016      89.0  kiauras      44.0      56         39     53
# 2020      71.0     91.0      91.0      54         89     24
# 2024      51.0     86.0      37.0      45         24     50

# %%
su_nuostoliu['Vilnius'].fillna(value=su_nuostoliu['Vilnius'].mean())
# Out:
# index
# 2000    99.000000
# 2004    22.000000
# 2008    62.666667
# 2012    44.000000
# 2016    89.000000
# 2020    71.000000
# 2024    51.000000
# Name: Vilnius, dtype: float64

# %%
su_nuostoliu.fillna(value=su_nuostoliu.mean())
# Out:
#          Vilnius     Kaunas  Panevezys  Alytus  Kavarskas  Utena
# index
# 2000   99.000000  61.000000       72.0      88         93     65
# 2004   22.000000  84.000000       75.0      84         55     61
# 2008   62.666667  51.000000       69.5      99         70     69
# 2012   44.000000  81.000000       98.0      33         29     59
# 2016   89.000000  75.666667       44.0      56         39     53
# 2020   71.000000  91.000000       91.0      54         89     24
# 2024   51.000000  86.000000       37.0      45         24     50

# %%
visi_miestai = su_utena.transpose()
visi_miestai
# Out:
# index      2000  2004  2008  2012  2016  2020  2024
# Vilnius      99    22    11    44    89    71    51
# Kaunas       61    84    51    81    11    91    86
# Panevezys    72    75    19    98    44    91    37
# Alytus       88    84    99    33    56    54    45
# Kavarskas    93    55    70    29    39    89    24
# Utena        65    61    69    59    53    24    50

# %%
regionai = pd.Series(['Miestas',
           'Miestas',
           'Aukstaityja',
           'Dzukyja',
           'MazojiLietuva',
           'Zemaityja'
])
laikini = visi_miestai.reset_index()
laikini['regionai'] = regionai
visi_miestai = laikini.set_index('index')
visi_miestai
# Out:
# index      2000  2004  2008  2012  2016  2020  2024       regionai
# index
# Vilnius      99    22    11    44    89    71    51        Miestas
# Kaunas       61    84    51    81    11    91    86        Miestas
# Panevezys    72    75    19    98    44    91    37    Aukstaityja
# Alytus       88    84    99    33    56    54    45        Dzukyja
# Kavarskas    93    55    70    29    39    89    24  MazojiLietuva
# Utena        65    61    69    59    53    24    50      Zemaityja

# %%
regionais = visi_miestai.groupby('regionai')
regionais.mean(numeric_only=True)
# Out:
# index          2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaityja    72.0  75.0  19.0  98.0  44.0  91.0  37.0
# Dzukyja        88.0  84.0  99.0  33.0  56.0  54.0  45.0
# MazojiLietuva  93.0  55.0  70.0  29.0  39.0  89.0  24.0
# Miestas        80.0  53.0  31.0  62.5  50.0  81.0  68.5
# Zemaityja      65.0  61.0  69.0  59.0  53.0  24.0  50.0

# %%
regionais.sum(numeric_only=True)
# Out:
# index          2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaityja      72    75    19    98    44    91    37
# Dzukyja          88    84    99    33    56    54    45
# MazojiLietuva    93    55    70    29    39    89    24
# Miestas         160   106    62   125   100   162   137
# Zemaityja        65    61    69    59    53    24    50

# %%
regionais.count()
# Out:
# index          2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaityja       1     1     1     1     1     1     1
# Dzukyja           1     1     1     1     1     1     1
# MazojiLietuva     1     1     1     1     1     1     1
# Miestas           2     2     2     2     2     2     2
# Zemaityja         1     1     1     1     1     1     1

# %%
regionais.max() - regionais.min()
# Out:
# index          2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaityja       0     0     0     0     0     0     0
# Dzukyja           0     0     0     0     0     0     0
# MazojiLietuva     0     0     0     0     0     0     0
# Miestas          38    62    40    37    78    20    35
# Zemaityja         0     0     0     0     0     0     0

# %%
regionais[2000].describe()
# Out:
#                count  mean        std   min   25%   50%   75%   max
# regionai
# Aukstaityja      1.0  72.0        NaN  72.0  72.0  72.0  72.0  72.0
# Dzukyja          1.0  88.0        NaN  88.0  88.0  88.0  88.0  88.0
# MazojiLietuva    1.0  93.0        NaN  93.0  93.0  93.0  93.0  93.0
# Miestas          2.0  80.0  26.870058  61.0  70.5  80.0  89.5  99.0
# Zemaityja        1.0  65.0        NaN  65.0  65.0  65.0  65.0  65.0

# %%
top = visi_miestai[:'Kavarskas'].copy()
bottom = visi_miestai[:'Vilnius'].copy()

# %%
bottom
# Out:
# index    2000  2004  2008  2012  2016  2020  2024 regionai
# index
# Vilnius    99    22    11    44    89    71    51  Miestas

# %%
pd.concat([top, bottom], axis=1)
# Out:
# index      2000  2004  2008  2012  2016  2020  2024       regionai  2000  \
# index
# Vilnius      99    22    11    44    89    71    51        Miestas  99.0
# Kaunas       61    84    51    81    11    91    86        Miestas   NaN
# Panevezys    72    75    19    98    44    91    37    Aukstaityja   NaN
# Alytus       88    84    99    33    56    54    45        Dzukyja   NaN
# Kavarskas    93    55    70    29    39    89    24  MazojiLietuva   NaN
#
# index      2004  2008  2012  2016  2020  2024 regionai
# index
# Vilnius    22.0  11.0  44.0  89.0  71.0  51.0  Miestas
# Kaunas      NaN   NaN   NaN   NaN   NaN   NaN      NaN
# Panevezys   NaN   NaN   NaN   NaN   NaN   NaN      NaN
# Alytus      NaN   NaN   NaN   NaN   NaN   NaN      NaN
# Kavarskas   NaN   NaN   NaN   NaN   NaN   NaN      NaN

# %%
right4 = top.reset_index()
right4. drop(columns='index', inplace=True)
right4
# Out:
# index  2000  2004  2008  2012  2016  2020  2024       regionai
# 0        99    22    11    44    89    71    51        Miestas
# 1        61    84    51    81    11    91    86        Miestas
# 2        72    75    19    98    44    91    37    Aukstaityja
# 3        88    84    99    33    56    54    45        Dzukyja
# 4        93    55    70    29    39    89    24  MazojiLietuva

# %%
left = top.reset_index().drop(columns='regionai')
left
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024
# 0        Vilnius    99    22    11    44    89    71    51
# 1         Kaunas    61    84    51    81    11    91    86
# 2      Panevezys    72    75    19    98    44    91    37
# 3         Alytus    88    84    99    33    56    54    45
# 4      Kavarskas    93    55    70    29    39    89    24

# %%
pd.concat([left, right4], axis=1)
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024  2000  2004  2008  \
# 0        Vilnius    99    22    11    44    89    71    51    99    22    11
# 1         Kaunas    61    84    51    81    11    91    86    61    84    51
# 2      Panevezys    72    75    19    98    44    91    37    72    75    19
# 3         Alytus    88    84    99    33    56    54    45    88    84    99
# 4      Kavarskas    93    55    70    29    39    89    24    93    55    70
#
# index  2012  2016  2020  2024       regionai
# 0        44    89    71    51        Miestas
# 1        81    11    91    86        Miestas
# 2        98    44    91    37    Aukstaityja
# 3        33    56    54    45        Dzukyja
# 4        29    39    89    24  MazojiLietuva

# %%
## duomenu skaitymas/rasymas

# %%
top = pd.read_csv('top50.csv', encoding='ISO-8859-1')
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %%
top['Genre'].unique()
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
top['Genre'].nunique()
# Out:
# 21

# %%
top['Genre'].value_counts()
# Out:
# Genre
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# reggaeton           2
# reggaeton flow      2
# panamanian pop      2
# canadian pop        2
# electropop          2
# country rap         2
# dfw rap             2
# brostep             2
# trap music          1
# escape room         1
# pop house           1
# australian pop      1
# atl hip hop         1
# big room            1
# boy band            1
# r&b en espanol      1
# Name: count, dtype: int64

# %%
top['Length.'].sum()
# Out:
# 10048

# %%
def minutes_seconds(length):
    return f'{length//60}:{(length % 60):02d}'

# %%
top['Length.'].apply(minutes_seconds).head()
# Out:
# 0    3:11
# 1    5:02
# 2    3:06
# 3    3:18
# 4    2:55
# Name: Length., dtype: object

# %%
top['Length.Pretty'] = top['Length.'].apply(minutes_seconds).head()
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 0      191               4             3          79          3:11
# 1      302               8             9          92          5:02
# 2      186              12            46          85          3:06
# 3      198              12            19          86          3:18
# 4      175              45             7          94          2:55

# %%
top['Energy'].apply(lambda energy:energy // 10).head()
# Out:
# 0    5
# 1    8
# 2    8
# 3    6
# 4    6
# Name: Energy, dtype: int64

# %%
top.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity',
#        'Length.Pretty'],
#       dtype='object')

# %%
top.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
top.shape
# Out:
# (50, 15)

# %%
top.sort_values('Beats.Per.Minute', ascending=False).head()
# Out:
#     Unnamed: 0                     Track.Name    Artist.Name           Genre  \
# 2            3  boyfriend (with Social House)  Ariana Grande       dance pop
# 6            7                         Ransom      Lil Tecca      trap music
# 10          11                       Callaita      Bad Bunny       reggaeton
# 36          37                     Otro Trago           Sech  panamanian pop
# 46          47                      Te Robaré      Nicky Jam           latin
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 2                190      80            40              -4        16
# 6                180      64            75              -6         7
# 10               176      62            61              -5        24
# 36               176      70            75              -5        11
# 46               176      75            67              -4         8
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 2         70      186              12            46          85          3:06
# 6         23      131               2            29          92           NaN
# 10        24      251              60            31          93           NaN
# 36        62      226              14            34          91           NaN
# 46        80      202              24             6          88           NaN

# %%
top_speed = top.sort_values('Beats.Per.Minute', ascending=False).head()
top_speed.to_csv('top50_fastest.csv', index=True, index_label = 'Top.Index')

# %%
excel_writer = pd.ExcelWriter('top_speed.xls', engine='xlswriter')
top_speed.to_excel(excel_writer, sheet_name='Fasterst BPM')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\io\excel\_util.py:93, in get_writer(engine_name)
#      92 try:
# ---> 93     return _writers[engine_name]
#      94 except KeyError as err:
#
# KeyError: 'xlswriter'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 excel_writer = pd.ExcelWriter('top_speed.xls', engine='xlswriter')
#       2 top_speed.to_excel(excel_writer, sheet_name='Fasterst BPM')
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\io\excel\_base.py:1146, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1143     assert engine is not None
#    1144     #  error: Incompatible types in assignment (expression has type
#    1145     #  "type[ExcelWriter[Any]]", variable has type "type[Self]")
# -> 1146     cls = get_writer(engine)  # type: ignore[assignment]
#    1148 return object.__new__(cls)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\io\excel\_util.py:95, in get_writer(engine_name)
#      93     return _writers[engine_name]
#      94 except KeyError as err:
# ---> 95     raise ValueError(f"No Excel writer '{engine_name}'") from err
#
# ValueError: No Excel writer 'xlswriter'

# %%
html_data = pd.read_html('https://lt.wikipedia.org/wiki/Vilniaus_miesto_savivaldyb%C4%97')
html_data[5]
# Out:
#                       Seniūnija Plotas km²  Gyventojai  (2023 m.)  \
# 0          Antakalnio seniūnija   77,2 km²                  43027
# 1        Fabijoniškių seniūnija   5,87 km²                  37360
# 2           Grigiškių seniūnija    7,1 km²                  10685
# 3         Justiniškių seniūnija   2,98 km²                  26263
# 4        Karoliniškių seniūnija    4,0 km²                  24643
# 5             Lazdynų seniūnija    9,9 km²                  32045
# 6        Naujamiesčio seniūnija    4,9 km²                  34668
# 7          Naujininkų seniūnija   41,1 km²                  36082
# 8   Naujosios Vilnios seniūnija   38,6 km²                  42545
# 9             Panerių seniūnija  84,94 km²                  11368
# 10         Pašilaičių seniūnija   8,07 km²                  43393
# 11           Pilaitės seniūnija   13,9 km²                  31373
# 12               Rasų seniūnija   16,3 km²                  12354
# 13        Senamiesčio seniūnija    4,5 km²                  25619
# 14           Šeškinės seniūnija    4,4 km²                  29558
# 15          Šnipiškių seniūnija   3,12 km²                  17270
# 16             Verkių seniūnija  55,94 km²                  55752
# 17          Vilkpėdės seniūnija   10,3 km²                  19608
# 18        Viršuliškių seniūnija    2,5 km²                  13821
# 19            Žirmūnų seniūnija    5,7 km²                  43976
# 20            Žvėryno seniūnija    2,6 km²                  14004
#
#    Gyventojų tankumas km²  (2023 m.)
# 0                        557 žm./km²
# 1                       6365 žm./km²
# 2                       1505 žm./km²
# 3                       8813 žm./km²
# 4                       6161 žm./km²
# 5                       3237 žm./km²
# 6                       7075 žm./km²
# 7                        878 žm./km²
# 8                       1102 žm./km²
# 9                        134 žm./km²
# 10                      5493 žm./km²
# 11                      2257 žm./km²
# 12                       758 žm./km²
# 13                      5693 žm./km²
# 14                      6718 žm./km²
# 15                      5535 žm./km²
# 16                       997 žm./km²
# 17                      1904 žm./km²
# 18                      5528 žm./km²
# 19                      7715 žm./km²
# 20                      5386 žm./km²

# %%
from sqlalchemy import create_engine
db_engine = create_engine('sqlite:///seniunijos.db')

# %%
seniunijos.to_sql('seniunijos', con=db_engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 seniunijos.to_sql('seniunijos', con=db_engine, index=False)
#
# NameError: name 'seniunijos' is not defined

# %%
school_engine = create_engine('sqlite:///db/school/school.db)')

# %%
schedule = pd.read_sql('schedule', con=school_engine)
schedule.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1268 if not fairy:
# -> 1269     fairy = _ConnectionRecord.checkout(pool)
#    1271     if threadconns is not None:
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\impl.py:169, in QueuePool._do_get(self)
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\impl.py:167, in QueuePool._do_get(self)
#     166 try:
# --> 167     return self._create_connection()
#     168 except:
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:902, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\create.py:645, in create_engine.<locals>.connect(connection_record)
#     643             return connection
# --> 645 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 schedule = pd.read_sql('schedule', con=school_engine)
#       2 schedule.head()
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\io\sql.py:704, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     701     dtype_backend = "numpy"  # type: ignore[assignment]
#     702 assert dtype_backend is not lib.no_default
# --> 704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
#     706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#    (...)
#     714             dtype=dtype,
#     715         )
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\io\sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\io\sql.py:1639, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1637     self.exit_stack.callback(con.dispose)
#    1638 if isinstance(con, Engine):
# -> 1639     con = self.exit_stack.enter_context(con.connect())
#    1640 if need_transaction and not con.in_transaction():
#    1641     self.exit_stack.enter_context(con.begin())
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\base.py:3269, in Engine.connect(self)
#    3246 def connect(self) -> Connection:
#    3247     """Return a new :class:`_engine.Connection` object.
#    3248
#    3249     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3266
#    3267     """
# -> 3269     return self._connection_cls(self)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\base.py:2431, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2429 elif should_wrap:
#    2430     assert sqlalchemy_exception is not None
# -> 2431     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2432 else:
#    2433     assert exc_info[1] is not None
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.raw_connection(self)
#    3271 def raw_connection(self) -> PoolProxiedConnection:
#    3272     """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274     The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292     """
# -> 3293     return self.pool.connect()
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1261 @classmethod
#    1262 def _checkout(
#    1263     cls,
#    (...)
#    1266     fairy: Optional[_ConnectionFairy] = None,
#    1267 ) -> _ConnectionFairy:
#    1268     if not fairy:
# -> 1269         fairy = _ConnectionRecord.checkout(pool)
#    1271         if threadconns is not None:
#    1272             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\impl.py:169, in QueuePool._do_get(self)
#     167     return self._create_connection()
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#     171     raise
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:902, in _ConnectionRecord.__connect(self)
#     900     self.fresh = True
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\create.py:645, in create_engine.<locals>.connect(connection_record)
#     642         if connection is not None:
#     643             return connection
# --> 645 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\sqlalchemy\engine\default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
