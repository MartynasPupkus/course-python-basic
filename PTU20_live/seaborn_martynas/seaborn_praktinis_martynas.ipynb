# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.shape
# Out:
# (244, 7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(tips['total_bill'])

# %%
sns.displot(tips['total_bill'], bins=5)

# %%
tb_min = min(tips['total_bill'])
tb_min
# Out:
# 3.07

# %%
tb_max = max(tips['total_bill'])
tb_max
# Out:
# 50.81

# %%
bars = np.linspace(tb_min, tb_max, 6)
bars
# Out:
# array([ 3.07 , 12.618, 22.166, 31.714, 41.262, 50.81 ])

# %%
total_bill = tips['total_bill']
bar1 = total_bill[(total_bill >= bars[0]) & (total_bill <= bars[1])]
bar2 = total_bill[(total_bill >= [bars[1]]) & (total_bill <= bars[2])]
print(len(bar1), len(bar2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 total_bill = tips['total_bill']
#       2 bar1 = total_bill[(total_bill >= bars[0]) & (total_bill <= bars[1])]
# ----> 3 bar2 = total_bill[(total_bill >= [bars[1]]) & (total_bill <= bars[2])]
#       4 print(len(bar1), len(bar2))
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\core\series.py:6099, in Series._cmp_method(self, other, op)
#    6096 lvalues = self._values
#    6097 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6099 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6101 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\Martynas\CodeAcademy\course-python-basic\venv\Lib\site-packages\pandas\core\ops\array_ops.py:321, in comparison_op(left, right, op)
#     316 if isinstance(rvalues, (np.ndarray, ABCExtensionArray)):
#     317     # TODO: make this treatment consistent across ops and classes.
#     318     #  We are not catching all listlikes here (e.g. frozenset, tuple)
#     319     #  The ambiguous case is object-dtype.  See GH#27803
#     320     if len(lvalues) != len(rvalues):
# --> 321         raise ValueError(
#     322             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     323         )
#     325 if should_extension_dispatch(lvalues, rvalues) or (
#     326     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     327     and lvalues.dtype != object
#     328 ):
#     329     # Call the method on lvalues
#     330     res_values = op(lvalues, rvalues)
#
# ValueError: ('Lengths must match to compare', (244,), (1,))

# %%
sns.jointplot(x='total_bill', y = 'tip', data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='reg')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='hist')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hist')

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='size', size='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(tips)

# %%
sns.scatterplot(x='total_bill', y='size', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.pairplot(tips, hue='sex', diag_kind='hist')

# %%
sns.set_palette('tab10')

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=sum, errorbar=('ci', False))
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.set_style('whitegrid')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.barplot(x='sex', y='total_bill', data=tips, hue='day', estimator=sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='smoker', data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.boxplot(x='smoker', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(x='sex', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
koreliacijos = tips.corr(numeric_only=True)
koreliacijos
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(koreliacijos, annot=True, cmap='BuPu')
# Out:
# <Axes: >

# %%
gridux = sns.FacetGrid(data=tips, col='time', row ='smoker')
gridux.map(sns.scatterplot,'tip', 'total_bill')
